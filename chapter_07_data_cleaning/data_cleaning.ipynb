# %%
# %pip install pandas
# %pip install numpy
# Out:
# Requirement already satisfied: pandas in c:\users\asus\appdata\local\programs\python\python312\lib\site-packages (3.0.5)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\asus\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\asus\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\asus\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2026.3)
# Requirement already satisfied: six>=1.5 in c:\users\asus\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy in c:\users\asus\appdata\local\programs\python\python312\lib\site-packages (2.5.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np

# %%
float_data = pd.Series([1.2, -3.5, np.nan, 0])

# %%
float_data
# Out:
# 0    1.2
# 1   -3.5
# 2    NaN
# 3    0.0
# dtype: float64

# %%
float_data.isna()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
string_data = pd.Series(["aardvark", np.nan, None, "avocado"])

# %%
string_data
# Out:
# 0    aardvark
# 1         NaN
# 2         NaN
# 3     avocado
# dtype: str

# %%
string_data.isna()
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# dtype: bool

# %%
float_data = pd.Series([1, 2, None], dtype='float64')

# %%
float_data
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# dtype: float64

# %%
float_data.isna()
# Out:
# 0    False
# 1    False
# 2     True
# dtype: bool

# %%
data = pd.Series([1, np.nan, 3.5, np.nan, 7])

# %%
data.dropna()
# Out:
# 0    1.0
# 2    3.5
# 4    7.0
# dtype: float64

# %%
data[data.notna()]
# Out:
# 0    1.0
# 2    3.5
# 4    7.0
# dtype: float64

# %%
data = pd.DataFrame([[1., 6.5, 3.], [1., np.nan, np.nan],
                     [np.nan, np.nan, np.nan], [np.nan, 6.5, 3.]])

# %%
data
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  6.5  3.0

# %%
data.dropna()
# Out:
#      0    1    2
# 0  1.0  6.5  3.0

# %%
data.dropna(how="all")
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 3  NaN  6.5  3.0

# %%
data[4] = np.nan

# %%
data
# Out:
#      0    1    2   4
# 0  1.0  6.5  3.0 NaN
# 1  1.0  NaN  NaN NaN
# 2  NaN  NaN  NaN NaN
# 3  NaN  6.5  3.0 NaN

# %%
data.dropna(axis="columns", how="all")
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  6.5  3.0

# %%
df = pd.DataFrame(np.random.standard_normal((7, 3)))

# %%
df.iloc[:4, 1] = np.nan

# %%
df.iloc[:2, 2] = np.nan

# %%
df
# Out:
#           0         1         2
# 0  0.869474       NaN       NaN
# 1  1.505949       NaN       NaN
# 2  0.394116       NaN -0.208928
# 3  1.325197       NaN  1.885672
# 4  1.134140  0.718775  0.290391
# 5  1.946938 -1.217105  0.861257
# 6 -0.210048  0.174519 -0.489095

# %%
df.dropna()
# Out:
#           0         1         2
# 4  1.134140  0.718775  0.290391
# 5  1.946938 -1.217105  0.861257
# 6 -0.210048  0.174519 -0.489095

# %%
df.dropna(thresh=2)
# Out:
#           0         1         2
# 2  0.394116       NaN -0.208928
# 3  1.325197       NaN  1.885672
# 4  1.134140  0.718775  0.290391
# 5  1.946938 -1.217105  0.861257
# 6 -0.210048  0.174519 -0.489095

# %%
df.fillna(0)
# Out:
#           0         1         2
# 0  0.869474  0.000000  0.000000
# 1  1.505949  0.000000  0.000000
# 2  0.394116  0.000000 -0.208928
# 3  1.325197  0.000000  1.885672
# 4  1.134140  0.718775  0.290391
# 5  1.946938 -1.217105  0.861257
# 6 -0.210048  0.174519 -0.489095

# %%
df.fillna({1: 0.5, 2: 0})
# Out:
#           0         1         2
# 0  0.869474  0.500000  0.000000
# 1  1.505949  0.500000  0.000000
# 2  0.394116  0.500000 -0.208928
# 3  1.325197  0.500000  1.885672
# 4  1.134140  0.718775  0.290391
# 5  1.946938 -1.217105  0.861257
# 6 -0.210048  0.174519 -0.489095

# %%
df = pd.DataFrame(np.random.standard_normal((6, 3)))

# %%
df.iloc[2:, 1] = np.nan

# %%
df.iloc[4:, 2] = np.nan

# %%
df
# Out:
#           0         1         2
# 0  1.010104  0.701211  0.872734
# 1  0.015454 -0.428248 -0.548710
# 2  1.260917       NaN -0.742558
# 3  0.168459       NaN  0.968934
# 4  0.838803       NaN       NaN
# 5 -1.798664       NaN       NaN

# %%
df.ffill()
# Out:
#           0         1         2
# 0  1.010104  0.701211  0.872734
# 1  0.015454 -0.428248 -0.548710
# 2  1.260917 -0.428248 -0.742558
# 3  0.168459 -0.428248  0.968934
# 4  0.838803 -0.428248  0.968934
# 5 -1.798664 -0.428248  0.968934

# %%
df.ffill(limit=2)
# Out:
#           0         1         2
# 0  1.010104  0.701211  0.872734
# 1  0.015454 -0.428248 -0.548710
# 2  1.260917 -0.428248 -0.742558
# 3  0.168459 -0.428248  0.968934
# 4  0.838803       NaN  0.968934
# 5 -1.798664       NaN  0.968934

# %%
data = pd.Series([1., np.nan, 3.5, np.nan, 7])

# %%
data.fillna(data.mean())
# Out:
# 0    1.000000
# 1    3.833333
# 2    3.500000
# 3    3.833333
# 4    7.000000
# dtype: float64

# %%
data = pd.DataFrame({"k1": ["one", "two"] * 3 + ["two"],
                     "k2": [1, 1, 2, 3, 3, 4, 4]})

# %%
data
# Out:
#     k1  k2
# 0  one   1
# 1  two   1
# 2  one   2
# 3  two   3
# 4  one   3
# 5  two   4
# 6  two   4

# %%
data.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# dtype: bool

# %%
data.drop_duplicates()
# Out:
#     k1  k2
# 0  one   1
# 1  two   1
# 2  one   2
# 3  two   3
# 4  one   3
# 5  two   4

# %%
data["v1"] = range(7)

# %%
data
# Out:
#     k1  k2  v1
# 0  one   1   0
# 1  two   1   1
# 2  one   2   2
# 3  two   3   3
# 4  one   3   4
# 5  two   4   5
# 6  two   4   6

# %%
data.drop_duplicates(subset=["k1"])
# Out:
#     k1  k2  v1
# 0  one   1   0
# 1  two   1   1

# %%
data.drop_duplicates(["k1", "k2"], keep="last")
# Out:
#     k1  k2  v1
# 0  one   1   0
# 1  two   1   1
# 2  one   2   2
# 3  two   3   3
# 4  one   3   4
# 6  two   4   6

# %%
data = pd.DataFrame({"food": ["bacon", "pulled pork", "bacon",
                              "pastrami", "corned beef", "bacon",
                              "pastrami", "honey ham", "nova lox"],
                    "ounces": [4, 3, 12, 6, 7.5, 8, 3, 5, 6]})

# %%
data
# Out:
#           food  ounces
# 0        bacon     4.0
# 1  pulled pork     3.0
# 2        bacon    12.0
# 3     pastrami     6.0
# 4  corned beef     7.5
# 5        bacon     8.0
# 6     pastrami     3.0
# 7    honey ham     5.0
# 8     nova lox     6.0

# %%
meat_to_animal = {
    "bacon": "pig",
    "pulled pork": "pig",
    "pastrami": "cow",
    "corned beef": "cow",
    "honey ham": "pig",
    "nova lox": "salmon"
}

# %%
data["animal"] = data["food"].map(meat_to_animal)

# %%
data
# Out:
#           food  ounces  animal
# 0        bacon     4.0     pig
# 1  pulled pork     3.0     pig
# 2        bacon    12.0     pig
# 3     pastrami     6.0     cow
# 4  corned beef     7.5     cow
# 5        bacon     8.0     pig
# 6     pastrami     3.0     cow
# 7    honey ham     5.0     pig
# 8     nova lox     6.0  salmon

# %%
def get_animal(x):
    return meat_to_animal[x]

# %%
data["food"].map(get_animal)
# Out:
# 0       pig
# 1       pig
# 2       pig
# 3       cow
# 4       cow
# 5       pig
# 6       cow
# 7       pig
# 8    salmon
# Name: food, dtype: str

# %%
data = pd.Series([1., -999., 2., -999., -1000., 3.])

# %%
data
# Out:
# 0       1.0
# 1    -999.0
# 2       2.0
# 3    -999.0
# 4   -1000.0
# 5       3.0
# dtype: float64

# %%
data.replace(-999, np.nan)
# Out:
# 0       1.0
# 1       NaN
# 2       2.0
# 3       NaN
# 4   -1000.0
# 5       3.0
# dtype: float64

# %%
data.replace([-999, -1000], np.nan)
# Out:
# 0    1.0
# 1    NaN
# 2    2.0
# 3    NaN
# 4    NaN
# 5    3.0
# dtype: float64

# %%
data.replace([-999, -1000], [np.nan, 0])
# Out:
# 0    1.0
# 1    NaN
# 2    2.0
# 3    NaN
# 4    0.0
# 5    3.0
# dtype: float64

# %%
data.replace({-999: np.nan, -1000: 0})
# Out:
# 0    1.0
# 1    NaN
# 2    2.0
# 3    NaN
# 4    0.0
# 5    3.0
# dtype: float64

# %%
data = pd.DataFrame(np.arange(12).reshape((3, 4)),
                    index=["Ohio", "Colorado", "New York"],
                    columns=["one", "two", "three", "four"])

# %%
def transform(x):
    return x[:4].upper()

# %%
data.index.map(transform)
# Out:
# Index(['OHIO', 'COLO', 'NEW '], dtype='str')

# %%
data.index = data.index.map(transform)

# %%
data
# Out:
#       one  two  three  four
# OHIO    0    1      2     3
# COLO    4    5      6     7
# NEW     8    9     10    11

# %%
data.rename(index=str.title, columns=str.upper)
# Out:
#       ONE  TWO  THREE  FOUR
# Ohio    0    1      2     3
# Colo    4    5      6     7
# New     8    9     10    11

# %%
data.rename(index={"OHIO": "INDIANA"},
            columns={"three": "peekaboo"})
# Out:
#          one  two  peekaboo  four
# INDIANA    0    1         2     3
# COLO       4    5         6     7
# NEW        8    9        10    11
