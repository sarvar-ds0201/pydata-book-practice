# %%
import numpy as np

# %%
import pandas as pd

# %%
from datetime import datetime

# %%
now = datetime.now()

# %%
now
# Out:
# datetime.datetime(2026, 8, 22, 12, 21, 59, 672956)

# %%
now.year, now.month, now.day
# Out:
# (2026, 8, 22)

# %%
delta = datetime(2011, 1, 7) - datetime(2008, 6, 24, 8, 15)

# %%
delta
# Out:
# datetime.timedelta(days=926, seconds=56700)

# %%
delta.days
# Out:
# 926

# %%
delta.seconds
# Out:
# 56700

# %%
from datetime import timedelta

# %%
start = datetime(2011, 1, 7)

# %%
start + timedelta(12)
# Out:
# datetime.datetime(2011, 1, 19, 0, 0)

# %%
start - 2 * timedelta(12)
# Out:
# datetime.datetime(2010, 12, 14, 0, 0)

# %%
stamp = datetime(2011, 1, 3)

# %%
str(stamp)
# Out:
# '2011-01-03 00:00:00'

# %%
stamp.strftime('%Y-%m-%d')
# Out:
# '2011-01-03'

# %%
value = '2011-01-03'

# %%
datetime.strptime(value, '%Y-%m-%d')
# Out:
# datetime.datetime(2011, 1, 3, 0, 0)

# %%
datestrs = ['7/6/2011', '8/6/2011']

# %%
[datetime.strptime(x, '%m/%d/%Y') for x in datestrs]
# Out:
# [datetime.datetime(2011, 7, 6, 0, 0), datetime.datetime(2011, 8, 6, 0, 0)]

# %%
datestrs = ['2011-07-06 12:00:00', '2011-08-06 00:00:00']

# %%
pd.to_datetime(datestrs)
# Out:
# DatetimeIndex(['2011-07-06 12:00:00', '2011-08-06 00:00:00'], dtype='datetime64[us]', freq=None)

# %%
idx = pd.to_datetime(datestrs + [None])

# %%
idx
# Out:
# DatetimeIndex(['2011-07-06 12:00:00', '2011-08-06 00:00:00', 'NaT'], dtype='datetime64[us]', freq=None)

# %%
idx[2]
# Out:
# NaT

# %%
pd.isna(idx)
# Out:
# array([False, False,  True])

# %%
dates = [datetime(2011, 1, 2), datetime(2011, 1, 5),
         datetime(2011, 1, 7), datetime(2011, 1, 8),
         datetime(2011, 1, 10), datetime(2011, 1, 12)]

# %%
ts = pd.Series(np.random.standard_normal(6), index=dates)

# %%
ts
# Out:
# 2011-01-02    1.745434
# 2011-01-05    0.382422
# 2011-01-07   -1.562803
# 2011-01-08    0.431812
# 2011-01-10   -0.243559
# 2011-01-12    0.613114
# dtype: float64

# %%
ts.index
# Out:
# DatetimeIndex(['2011-01-02', '2011-01-05', '2011-01-07', '2011-01-08',
#                '2011-01-10', '2011-01-12'],
#               dtype='datetime64[us]', freq=None)

# %%
ts + ts[::2]
# Out:
# 2011-01-02    3.490869
# 2011-01-05         NaN
# 2011-01-07   -3.125607
# 2011-01-08         NaN
# 2011-01-10   -0.487118
# 2011-01-12         NaN
# dtype: float64

# %%
ts.index.dtype
# Out:
# dtype('<M8[us]')

# %%
stamp = ts.index[0]

# %%
stamp
# Out:
# Timestamp('2011-01-02 00:00:00')

# %%
stamp = ts.index[2]

# %%
ts[stamp]
# Out:
# np.float64(-1.5628033416157334)

# %%
ts['2011-01-10']
# Out:
# np.float64(-0.24355895752500695)

# %%
longer_ts = pd.Series(np.random.standard_normal(1000),
index=pd.date_range('2000-01-01', periods=1000))

# %%
longer_ts
# Out:
# 2000-01-01    0.185386
# 2000-01-02    0.644352
# 2000-01-03    0.357127
# 2000-01-04    0.312857
# 2000-01-05    0.565901
#                 ...
# 2002-09-22    0.862502
# 2002-09-23    1.018119
# 2002-09-24   -0.661771
# 2002-09-25    0.553870
# 2002-09-26   -0.590769
# Freq: D, Length: 1000, dtype: float64

# %%
longer_ts['2001']
# Out:
# 2001-01-01   -1.013364
# 2001-01-02   -1.911188
# 2001-01-03    0.009417
# 2001-01-04    0.461436
# 2001-01-05    0.036319
#                 ...
# 2001-12-27    0.866183
# 2001-12-28   -0.233913
# 2001-12-29    0.850981
# 2001-12-30   -0.107716
# 2001-12-31   -0.081893
# Freq: D, Length: 365, dtype: float64

# %%
longer_ts['2001-05']
# Out:
# 2001-05-01   -0.381771
# 2001-05-02   -0.109870
# 2001-05-03    0.325191
# 2001-05-04    0.756896
# 2001-05-05   -1.855835
# 2001-05-06    0.686271
# 2001-05-07   -0.137277
# 2001-05-08    0.043951
# 2001-05-09   -2.612760
# 2001-05-10   -0.373636
# 2001-05-11    0.515440
# 2001-05-12   -0.209485
# 2001-05-13    0.226976
# 2001-05-14   -1.242241
# 2001-05-15    0.360346
# 2001-05-16   -0.934700
# 2001-05-17    1.512167
# 2001-05-18    1.028158
# 2001-05-19   -0.619350
# 2001-05-20   -0.856782
# 2001-05-21   -1.297858
# 2001-05-22   -0.972744
# 2001-05-23    1.272176
# 2001-05-24   -0.511700
# 2001-05-25   -0.949187
# 2001-05-26    0.486404
# 2001-05-27    0.321412
# 2001-05-28    1.333171
# 2001-05-29    0.606650
# 2001-05-30   -2.066664
# 2001-05-31   -0.646639
# Freq: D, dtype: float64

# %%
ts[datetime(2011, 1, 7):]
# Out:
# 2011-01-07   -1.562803
# 2011-01-08    0.431812
# 2011-01-10   -0.243559
# 2011-01-12    0.613114
# dtype: float64

# %%
ts[datetime(2011, 1, 7):datetime(2001, 1, 10)]
# Out:
# Series([], dtype: float64)

# %%
ts
# Out:
# 2011-01-02    1.745434
# 2011-01-05    0.382422
# 2011-01-07   -1.562803
# 2011-01-08    0.431812
# 2011-01-10   -0.243559
# 2011-01-12    0.613114
# dtype: float64

# %%
ts['2011-01-06':'2011-01-11']
# Out:
# 2011-01-07   -1.562803
# 2011-01-08    0.431812
# 2011-01-10   -0.243559
# dtype: float64

# %%
ts.truncate(after='2011-01-09')
# Out:
# 2011-01-02    1.745434
# 2011-01-05    0.382422
# 2011-01-07   -1.562803
# 2011-01-08    0.431812
# dtype: float64

# %%
dates = pd.date_range('2000-01-01',periods=100, freq='W-WED')

# %%
long_df = pd.DataFrame(np.random.standard_normal((100, 4)),
                       index=dates,
                       columns=['Colorado', 'Texas',
                                'New York', 'Ohio'])

# %%
long_df.loc['2001-05']
# Out:
#             Colorado     Texas  New York      Ohio
# 2001-05-02  0.199124 -0.548573 -0.697409  0.361885
# 2001-05-09 -1.200527 -0.544956  0.174937  0.503332
# 2001-05-16 -1.456580 -0.245776  0.733396 -1.645125
# 2001-05-23  0.685720  0.735315 -0.627114 -0.692415
# 2001-05-30  1.390562 -0.262250 -0.740501  0.133004

# %%
dates = pd.DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-02',
                          '2000-01-02', '2000-01-03'])

# %%
dup_ts = pd.Series(np.arange(5), index=dates)

# %%
dup_ts
# Out:
# 2000-01-01    0
# 2000-01-02    1
# 2000-01-02    2
# 2000-01-02    3
# 2000-01-03    4
# dtype: int64

# %%
dup_ts.index.is_unique
# Out:
# False

# %%
dup_ts['2000-01-03']
# Out:
# np.int64(4)

# %%
dup_ts['2000-01-02']
# Out:
# 2000-01-02    1
# 2000-01-02    2
# 2000-01-02    3
# dtype: int64

# %%
grouped = dup_ts.groupby(level=0)

# %%
grouped.mean()
# Out:
# 2000-01-01    0.0
# 2000-01-02    2.0
# 2000-01-03    4.0
# dtype: float64

# %%
grouped.count()
# Out:
# 2000-01-01    1
# 2000-01-02    3
# 2000-01-03    1
# dtype: int64

# %%
ts
# Out:
# 2011-01-02    1.745434
# 2011-01-05    0.382422
# 2011-01-07   -1.562803
# 2011-01-08    0.431812
# 2011-01-10   -0.243559
# 2011-01-12    0.613114
# dtype: float64

# %%
resampler = ts.resample('D')

# %%
resampler

# %%
index = pd.date_range('2012-04-01','2012-06-01')

# %%
index
# Out:
# DatetimeIndex(['2012-04-01', '2012-04-02', '2012-04-03', '2012-04-04',
#                '2012-04-05', '2012-04-06', '2012-04-07', '2012-04-08',
#                '2012-04-09', '2012-04-10', '2012-04-11', '2012-04-12',
#                '2012-04-13', '2012-04-14', '2012-04-15', '2012-04-16',
#                '2012-04-17', '2012-04-18', '2012-04-19', '2012-04-20',
#                '2012-04-21', '2012-04-22', '2012-04-23', '2012-04-24',
#                '2012-04-25', '2012-04-26', '2012-04-27', '2012-04-28',
#                '2012-04-29', '2012-04-30', '2012-05-01', '2012-05-02',
#                '2012-05-03', '2012-05-04', '2012-05-05', '2012-05-06',
#                '2012-05-07', '2012-05-08', '2012-05-09', '2012-05-10',
#                '2012-05-11', '2012-05-12', '2012-05-13', '2012-05-14',
#                '2012-05-15', '2012-05-16', '2012-05-17', '2012-05-18',
#                '2012-05-19', '2012-05-20', '2012-05-21', '2012-05-22',
#                '2012-05-23', '2012-05-24', '2012-05-25', '2012-05-26',
#                '2012-05-27', '2012-05-28', '2012-05-29', '2012-05-30',
#                '2012-05-31', '2012-06-01'],
#               dtype='datetime64[us]', freq='D')

# %%
pd.date_range(start='2012-04-01', periods=20)
# Out:
# DatetimeIndex(['2012-04-01', '2012-04-02', '2012-04-03', '2012-04-04',
#                '2012-04-05', '2012-04-06', '2012-04-07', '2012-04-08',
#                '2012-04-09', '2012-04-10', '2012-04-11', '2012-04-12',
#                '2012-04-13', '2012-04-14', '2012-04-15', '2012-04-16',
#                '2012-04-17', '2012-04-18', '2012-04-19', '2012-04-20'],
#               dtype='datetime64[us]', freq='D')

# %%
pd.date_range(end='2012-06-01', periods=20)
# Out:
# DatetimeIndex(['2012-05-13', '2012-05-14', '2012-05-15', '2012-05-16',
#                '2012-05-17', '2012-05-18', '2012-05-19', '2012-05-20',
#                '2012-05-21', '2012-05-22', '2012-05-23', '2012-05-24',
#                '2012-05-25', '2012-05-26', '2012-05-27', '2012-05-28',
#                '2012-05-29', '2012-05-30', '2012-05-31', '2012-06-01'],
#               dtype='datetime64[us]', freq='D')

# %%
pd.date_range('2000-01-01', '2000-12-01', freq='BME')
# Out:
# DatetimeIndex(['2000-01-31', '2000-02-29', '2000-03-31', '2000-04-28',
#                '2000-05-31', '2000-06-30', '2000-07-31', '2000-08-31',
#                '2000-09-29', '2000-10-31', '2000-11-30'],
#               dtype='datetime64[us]', freq='BME')

# %%
pd.date_range('2012-05-02 12:56:31', periods=5)
# Out:
# DatetimeIndex(['2012-05-02 12:56:31', '2012-05-03 12:56:31',
#                '2012-05-04 12:56:31', '2012-05-05 12:56:31',
#                '2012-05-06 12:56:31'],
#               dtype='datetime64[us]', freq='D')

# %%
pd.date_range('2012-05-02 12:56:31', periods=5, normalize=True)
# Out:
# DatetimeIndex(['2012-05-02', '2012-05-03', '2012-05-04', '2012-05-05',
#                '2012-05-06'],
#               dtype='datetime64[us]', freq='D')

# %%
from pandas.tseries.offsets import Hour,  Minute

# %%
hour = Hour()

# %%
hour

# %%
four_hours = Hour(4)

# %%
four_hours
# Out:
# <4 * Hours>

# %%
pd.date_range('2000-01-01', '2000-01-03 23:59', freq='4h')
# Out:
# DatetimeIndex(['2000-01-01 00:00:00', '2000-01-01 04:00:00',
#                '2000-01-01 08:00:00', '2000-01-01 12:00:00',
#                '2000-01-01 16:00:00', '2000-01-01 20:00:00',
#                '2000-01-02 00:00:00', '2000-01-02 04:00:00',
#                '2000-01-02 08:00:00', '2000-01-02 12:00:00',
#                '2000-01-02 16:00:00', '2000-01-02 20:00:00',
#                '2000-01-03 00:00:00', '2000-01-03 04:00:00',
#                '2000-01-03 08:00:00', '2000-01-03 12:00:00',
#                '2000-01-03 16:00:00', '2000-01-03 20:00:00'],
#               dtype='datetime64[us]', freq='4h')

# %%
Hour(2) + Minute(30)
# Out:
# <150 * Minutes>

# %%
pd.date_range('2000-01-01', periods=10, freq='1h30min')
# Out:
# DatetimeIndex(['2000-01-01 00:00:00', '2000-01-01 01:30:00',
#                '2000-01-01 03:00:00', '2000-01-01 04:30:00',
#                '2000-01-01 06:00:00', '2000-01-01 07:30:00',
#                '2000-01-01 09:00:00', '2000-01-01 10:30:00',
#                '2000-01-01 12:00:00', '2000-01-01 13:30:00'],
#               dtype='datetime64[us]', freq='90min')

# %%
monthly_dates = pd.date_range('2012-01-01', '2012-09-01', freq='WOM-3FRI')

# %%
list(monthly_dates)
# Out:
# [Timestamp('2012-01-20 00:00:00'),
#  Timestamp('2012-02-17 00:00:00'),
#  Timestamp('2012-03-16 00:00:00'),
#  Timestamp('2012-04-20 00:00:00'),
#  Timestamp('2012-05-18 00:00:00'),
#  Timestamp('2012-06-15 00:00:00'),
#  Timestamp('2012-07-20 00:00:00'),
#  Timestamp('2012-08-17 00:00:00')]

# %%
ts = pd.Series(np.random.standard_normal(4),
                index=pd.date_range('2000-01-01', periods=4, freq='ME'))

# %%
ts
# Out:
# 2000-01-31    1.112854
# 2000-02-29    0.182922
# 2000-03-31    0.809493
# 2000-04-30    1.278007
# Freq: ME, dtype: float64

# %%
ts.shift(2)
# Out:
# 2000-01-31         NaN
# 2000-02-29         NaN
# 2000-03-31    1.112854
# 2000-04-30    0.182922
# Freq: ME, dtype: float64

# %%
ts.shift(-2)
# Out:
# 2000-01-31    0.809493
# 2000-02-29    1.278007
# 2000-03-31         NaN
# 2000-04-30         NaN
# Freq: ME, dtype: float64

# %%
ts.shift(2, freq='ME')
# Out:
# 2000-03-31    1.112854
# 2000-04-30    0.182922
# 2000-05-31    0.809493
# 2000-06-30    1.278007
# Freq: ME, dtype: float64

# %%
ts.shift(3, freq='D')
# Out:
# 2000-02-03    1.112854
# 2000-03-03    0.182922
# 2000-04-03    0.809493
# 2000-05-03    1.278007
# dtype: float64

# %%
ts.shift(1, freq='90min')
# Out:
# 2000-01-31 01:30:00    1.112854
# 2000-02-29 01:30:00    0.182922
# 2000-03-31 01:30:00    0.809493
# 2000-04-30 01:30:00    1.278007
# dtype: float64

# %%
from pandas.tseries.offsets import Day, MonthEnd

# %%
now = datetime(2011, 11, 17)

# %%
now + 3 * Day()
# Out:
# Timestamp('2011-11-20 00:00:00')

# %%
now + MonthEnd()
# Out:
# Timestamp('2011-11-30 00:00:00')

# %%
now + MonthEnd(2)
# Out:
# Timestamp('2011-12-31 00:00:00')

# %%
offset = MonthEnd()

# %%
offset.rollforward(now)
# Out:
# Timestamp('2011-11-30 00:00:00')

# %%
offset.rollback(now)
# Out:
# Timestamp('2011-10-31 00:00:00')

# %%
ts = pd.Series(np.random.standard_normal(20),
index=pd.date_range('2000-01-15', periods=20, freq='4D'))

# %%
ts
# Out:
# 2000-01-15    2.602286
# 2000-01-19    1.122729
# 2000-01-23    0.352331
# 2000-01-27   -1.073601
# 2000-01-31   -0.168386
# 2000-02-04   -1.307589
# 2000-02-08    0.931507
# 2000-02-12    0.107007
# 2000-02-16   -0.134403
# 2000-02-20   -0.317317
# 2000-02-24   -0.825478
# 2000-02-28   -1.064032
# 2000-03-03    0.884866
# 2000-03-07    1.076186
# 2000-03-11    0.420627
# 2000-03-15    1.513377
# 2000-03-19    1.949999
# 2000-03-23    0.478566
# 2000-03-27    2.630733
# 2000-03-31   -1.945041
# Freq: 4D, dtype: float64

# %%
ts.groupby(MonthEnd().rollforward).mean()
# Out:
# 2000-01-31    0.567072
# 2000-02-29   -0.372901
# 2000-03-31    0.876164
# dtype: float64

# %%
ts.resample('ME').mean()
# Out:
# 2000-01-31    0.567072
# 2000-02-29   -0.372901
# 2000-03-31    0.876164
# Freq: ME, dtype: float64

# %%
# %pip install -q pytz
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pytz

# %%
pytz.common_timezones[-5:]
# Out:
# ['US/Eastern', 'US/Hawaii', 'US/Mountain', 'US/Pacific', 'UTC']

# %%
tz = pytz.timezone('America/New_York')

# %%
tz
# Out:
# <DstTzInfo 'America/New_York' LMT-1 day, 19:04:00 STD>

# %%
dates = pd.date_range('2012-03-09 09:30', periods=6)

# %%
ts = pd.Series(np.random.standard_normal(len(dates)), index=dates)

# %%
ts
# Out:
# 2012-03-09 09:30:00   -0.271598
# 2012-03-10 09:30:00    0.394159
# 2012-03-11 09:30:00    0.294494
# 2012-03-12 09:30:00   -1.378160
# 2012-03-13 09:30:00    0.299579
# 2012-03-14 09:30:00    0.809282
# Freq: D, dtype: float64

# %%
print(ts.index.tz)
# Out:
# None

# %%
pd.date_range('2012-03-09 09:30', periods=10, tz='UTC')
# Out:
# DatetimeIndex(['2012-03-09 09:30:00+00:00', '2012-03-10 09:30:00+00:00',
#                '2012-03-11 09:30:00+00:00', '2012-03-12 09:30:00+00:00',
#                '2012-03-13 09:30:00+00:00', '2012-03-14 09:30:00+00:00',
#                '2012-03-15 09:30:00+00:00', '2012-03-16 09:30:00+00:00',
#                '2012-03-17 09:30:00+00:00', '2012-03-18 09:30:00+00:00'],
#               dtype='datetime64[us, UTC]', freq='D')

# %%
ts
# Out:
# 2012-03-09 09:30:00   -0.271598
# 2012-03-10 09:30:00    0.394159
# 2012-03-11 09:30:00    0.294494
# 2012-03-12 09:30:00   -1.378160
# 2012-03-13 09:30:00    0.299579
# 2012-03-14 09:30:00    0.809282
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize('UTC')

# %%
ts_utc
# Out:
# 2012-03-09 09:30:00+00:00   -0.271598
# 2012-03-10 09:30:00+00:00    0.394159
# 2012-03-11 09:30:00+00:00    0.294494
# 2012-03-12 09:30:00+00:00   -1.378160
# 2012-03-13 09:30:00+00:00    0.299579
# 2012-03-14 09:30:00+00:00    0.809282
# Freq: D, dtype: float64

# %%
ts_utc.index
# Out:
# DatetimeIndex(['2012-03-09 09:30:00+00:00', '2012-03-10 09:30:00+00:00',
#                '2012-03-11 09:30:00+00:00', '2012-03-12 09:30:00+00:00',
#                '2012-03-13 09:30:00+00:00', '2012-03-14 09:30:00+00:00'],
#               dtype='datetime64[us, UTC]', freq='D')

# %%
ts_utc.tz_convert('America/New_York')
# Out:
# 2012-03-09 04:30:00-05:00   -0.271598
# 2012-03-10 04:30:00-05:00    0.394159
# 2012-03-11 05:30:00-04:00    0.294494
# 2012-03-12 05:30:00-04:00   -1.378160
# 2012-03-13 05:30:00-04:00    0.299579
# 2012-03-14 05:30:00-04:00    0.809282
# dtype: float64

# %%
ts_eastern = ts.tz_localize('America/New_York')

# %%
ts_eastern.tz_convert('UTC')
# Out:
# 2012-03-09 14:30:00+00:00   -0.271598
# 2012-03-10 14:30:00+00:00    0.394159
# 2012-03-11 13:30:00+00:00    0.294494
# 2012-03-12 13:30:00+00:00   -1.378160
# 2012-03-13 13:30:00+00:00    0.299579
# 2012-03-14 13:30:00+00:00    0.809282
# dtype: float64

# %%
ts_eastern.tz_convert('Europe/Berlin')
# Out:
# 2012-03-09 15:30:00+01:00   -0.271598
# 2012-03-10 15:30:00+01:00    0.394159
# 2012-03-11 14:30:00+01:00    0.294494
# 2012-03-12 14:30:00+01:00   -1.378160
# 2012-03-13 14:30:00+01:00    0.299579
# 2012-03-14 14:30:00+01:00    0.809282
# dtype: float64

# %%
ts.index.tz_localize('Asia/Shanghai')
# Out:
# DatetimeIndex(['2012-03-09 09:30:00+08:00', '2012-03-10 09:30:00+08:00',
#                '2012-03-11 09:30:00+08:00', '2012-03-12 09:30:00+08:00',
#                '2012-03-13 09:30:00+08:00', '2012-03-14 09:30:00+08:00'],
#               dtype='datetime64[us, Asia/Shanghai]', freq=None)

# %%
stamp = pd.Timestamp('2011-03-12 04:00')

# %%
stamp_utc = stamp.tz_localize('utc')

# %%
stamp_utc.tz_convert('America/New_York')
# Out:
# Timestamp('2011-03-11 23:00:00-0500', tz='America/New_York')

# %%
stamp_moscow = pd.Timestamp('2011-03-12 04:00', tz='Europe/Moscow')

# %%
stamp_moscow
# Out:
# Timestamp('2011-03-12 04:00:00+0300', tz='Europe/Moscow')

# %%
stamp_utc.value
# Out:
# 1299902400000000000

# %%
stamp_utc.tz_convert('America/New_York').value
# Out:
# 1299902400000000000

# %%
stamp = pd.Timestamp('2012-03-11 01:30', tz='US/Eastern')

# %%
stamp
# Out:
# Timestamp('2012-03-11 01:30:00-0500', tz='US/Eastern')

# %%
stamp + Hour()
# Out:
# Timestamp('2012-03-11 03:30:00-0400', tz='US/Eastern')

# %%
stamp = pd.Timestamp('2012-11-04 00:30', tz='US/Eastern')

# %%
stamp
# Out:
# Timestamp('2012-11-04 00:30:00-0400', tz='US/Eastern')

# %%
stamp + 2 * Hour()
# Out:
# Timestamp('2012-11-04 01:30:00-0500', tz='US/Eastern')

# %%
dates = pd.date_range('2012-03-07 09:30', periods=10, freq='B')

# %%
ts = pd.Series(np.random.standard_normal(len(dates)), index=dates)

# %%
ts
# Out:
# 2012-03-07 09:30:00    0.868154
# 2012-03-08 09:30:00    0.941011
# 2012-03-09 09:30:00   -1.142707
# 2012-03-12 09:30:00    1.469400
# 2012-03-13 09:30:00   -0.313381
# 2012-03-14 09:30:00   -0.415110
# 2012-03-15 09:30:00   -0.402017
# 2012-03-16 09:30:00   -0.541215
# 2012-03-19 09:30:00   -0.278184
# 2012-03-20 09:30:00   -0.192405
# Freq: B, dtype: float64

# %%
ts1 = ts[:7].tz_localize('Europe/London')

# %%
ts2 = ts1[2:].tz_convert('Europe/Moscow')

# %%
result = ts1 + ts2

# %%
result.index
# Out:
# DatetimeIndex(['2012-03-07 09:30:00+00:00', '2012-03-08 09:30:00+00:00',
#                '2012-03-09 09:30:00+00:00', '2012-03-12 09:30:00+00:00',
#                '2012-03-13 09:30:00+00:00', '2012-03-14 09:30:00+00:00',
#                '2012-03-15 09:30:00+00:00'],
#               dtype='datetime64[us, UTC]', freq=None)

# %%
p = pd.Period('2011', freq='Y-DEC')

# %%
p
# Out:
# Period('2011', 'Y-DEC')

# %%
p + 5
# Out:
# Period('2016', 'Y-DEC')

# %%
p - 2
# Out:
# Period('2009', 'Y-DEC')

# %%
pd.Period('2014', freq='Y-DEC') - p
# Out:
# <3 * YearEnds: month=12>

# %%
periods = pd.period_range('2000-01-01', '2000-06-30', freq='M')

# %%
periods
# Out:
# PeriodIndex(['2000-01', '2000-02', '2000-03', '2000-04', '2000-05', '2000-06'], dtype='period[M]')

# %%
pd.Series(np.random.standard_normal(6), index=periods)
# Out:
# 2000-01    0.002741
# 2000-02   -0.916692
# 2000-03    1.350378
# 2000-04   -1.167284
# 2000-05   -1.140844
# 2000-06    0.656414
# Freq: M, dtype: float64

# %%
values = ['2001Q3', '2002Q2', '2003Q1']

# %%
index = pd.PeriodIndex(values, freq='Q-DEC')

# %%
index
# Out:
# PeriodIndex(['2001Q3', '2002Q2', '2003Q1'], dtype='period[Q-DEC]')

# %%
p = pd.Period('2011', freq='Y-DEC')

# %%
p
# Out:
# Period('2011', 'Y-DEC')

# %%
p.asfreq('M', how='start')
# Out:
# Period('2011-01', 'M')

# %%
p.asfreq('M', how='end')
# Out:
# Period('2011-12', 'M')

# %%
p.asfreq('M')
# Out:
# Period('2011-12', 'M')

# %%
p = pd.Period('2011', freq='Y-JUN')

# %%
p
# Out:
# Period('2011', 'Y-JUN')

# %%
p.asfreq('M', how='start')
# Out:
# Period('2010-07', 'M')

# %%
p.asfreq('M', how='end')
# Out:
# Period('2011-06', 'M')

# %%
p = pd.Period('Aug-2011', 'M')

# %%
p.asfreq('Y-JUN')
# Out:
# Period('2012', 'Y-JUN')

# %%
periods = pd.period_range('2006', '2009', freq='Y-DEC')

# %%
ts = pd.Series(np.random.standard_normal(len(periods)), index=periods)

# %%
ts
# Out:
# 2006   -1.426705
# 2007   -0.223108
# 2008    1.231422
# 2009    0.500969
# Freq: Y-DEC, dtype: float64

# %%
ts.asfreq('M', how='start')
# Out:
# 2006-01   -1.426705
# 2007-01   -0.223108
# 2008-01    1.231422
# 2009-01    0.500969
# Freq: M, dtype: float64

# %%
ts.asfreq('B', how='end')

# %%
p = pd.Period('2012Q4', freq='Q-JAN')

# %%
p
# Out:
# Period('2012Q4', 'Q-JAN')

# %%
p.asfreq('D', how='start')
# Out:
# Period('2011-11-01', 'D')

# %%
p.asfreq('D', how='end')
# Out:
# Period('2012-01-31', 'D')

# %%
p4pm = (p.asfreq('B', how='end') - 1).asfreq('min', how='start') + 16 * 60
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_12676\2530592745.py:1: FutureWarning: Period with BDay freq is deprecated and will be removed in a future version. Use a DatetimeIndex with BDay freq instead.
#   p4pm = (p.asfreq('B', how='end') - 1).asfreq('min', how='start') + 16 * 60

# %%
p4pm
# Out:
# Period('2012-01-30 16:00', 'min')

# %%
p4pm.to_timestamp()
# Out:
# Timestamp('2012-01-30 16:00:00')

# %%
periods = pd.period_range('2011Q3', '2012Q4', freq='Q-JAN')

# %%
ts = pd.Series(np.arange(len(periods)), index=periods)

# %%
ts
# Out:
# 2011Q3    0
# 2011Q4    1
# 2012Q1    2
# 2012Q2    3
# 2012Q3    4
# 2012Q4    5
# Freq: Q-JAN, dtype: int64

# %%
new_periods = (periods.asfreq('B', 'end') -1).asfreq('h', 'start') + 16

# %%
ts.index = new_periods.to_timestamp()

# %%
ts
# Out:
# 2010-10-28 16:00:00    0
# 2011-01-28 16:00:00    1
# 2011-04-28 16:00:00    2
# 2011-07-28 16:00:00    3
# 2011-10-28 16:00:00    4
# 2012-01-30 16:00:00    5
# dtype: int64

# %%
dates = pd.date_range('2000-01-01', periods=3, freq='ME')

# %%
ts = pd.Series(np.random.standard_normal(3), index=dates)

# %%
ts
# Out:
# 2000-01-31    1.488803
# 2000-02-29   -1.138257
# 2000-03-31    0.416809
# Freq: ME, dtype: float64

# %%
pts = ts.to_period()

# %%
pts
# Out:
# 2000-01    1.488803
# 2000-02   -1.138257
# 2000-03    0.416809
# Freq: M, dtype: float64

# %%
dates = pd.date_range('2000-01-29', periods=6)

# %%
ts2 = pd.Series(np.random.standard_normal(6), index=dates)

# %%
ts2
# Out:
# 2000-01-29    0.454367
# 2000-01-30   -0.014349
# 2000-01-31   -2.171173
# 2000-02-01   -0.798948
# 2000-02-02   -0.620968
# 2000-02-03   -0.161454
# Freq: D, dtype: float64

# %%
ts2.to_period('M')
# Out:
# 2000-01    0.454367
# 2000-01   -0.014349
# 2000-01   -2.171173
# 2000-02   -0.798948
# 2000-02   -0.620968
# 2000-02   -0.161454
# Freq: M, dtype: float64

# %%
pts = ts2.to_period()

# %%
pts
# Out:
# 2000-01-29    0.454367
# 2000-01-30   -0.014349
# 2000-01-31   -2.171173
# 2000-02-01   -0.798948
# 2000-02-02   -0.620968
# 2000-02-03   -0.161454
# Freq: D, dtype: float64

# %%
pts.to_timestamp(how='end')
# Out:
# 2000-01-29 23:59:59.999999    0.454367
# 2000-01-30 23:59:59.999999   -0.014349
# 2000-01-31 23:59:59.999999   -2.171173
# 2000-02-01 23:59:59.999999   -0.798948
# 2000-02-02 23:59:59.999999   -0.620968
# 2000-02-03 23:59:59.999999   -0.161454
# Freq: D, dtype: float64

# %%
data = pd.read_csv('../examples/macrodata.csv')

# %%
data.head(5)
# Out:
#    year  quarter   realgdp  realcons  realinv  realgovt  realdpi    cpi  \
# 0  1959        1  2710.349    1707.4  286.898   470.045   1886.9  28.98
# 1  1959        2  2778.801    1733.7  310.859   481.301   1919.7  29.15
# 2  1959        3  2775.488    1751.8  289.226   491.260   1916.4  29.35
# 3  1959        4  2785.204    1753.7  299.356   484.052   1931.3  29.37
# 4  1960        1  2847.699    1770.5  331.722   462.199   1955.5  29.54
#
#       m1  tbilrate  unemp      pop  infl  realint
# 0  139.7      2.82    5.8  177.146  0.00     0.00
# 1  141.7      3.08    5.1  177.830  2.34     0.74
# 2  140.5      3.82    5.3  178.657  2.74     1.09
# 3  140.0      4.33    5.6  179.386  0.27     4.06
# 4  139.6      3.50    5.2  180.007  2.31     1.19

# %%
data['year']
# Out:
# 0      1959
# 1      1959
# 2      1959
# 3      1959
# 4      1960
#        ...
# 198    2008
# 199    2008
# 200    2009
# 201    2009
# 202    2009
# Name: year, Length: 203, dtype: int64

# %%
data['quarter']
# Out:
# 0      1
# 1      2
# 2      3
# 3      4
# 4      1
#       ..
# 198    3
# 199    4
# 200    1
# 201    2
# 202    3
# Name: quarter, Length: 203, dtype: int64

# %%
index = pd.PeriodIndex(data['year'].astype(str) + 'Q' + data['quarter'].astype(str), freq='Q-DEC')

# %%
index
# Out:
# PeriodIndex(['1959Q1', '1959Q2', '1959Q3', '1959Q4', '1960Q1', '1960Q2',
#              '1960Q3', '1960Q4', '1961Q1', '1961Q2',
#              ...
#              '2007Q2', '2007Q3', '2007Q4', '2008Q1', '2008Q2', '2008Q3',
#              '2008Q4', '2009Q1', '2009Q2', '2009Q3'],
#             dtype='period[Q-DEC]', length=203)

# %%
data.index = index

# %%
data['infl']
# Out:
# 1959Q1    0.00
# 1959Q2    2.34
# 1959Q3    2.74
# 1959Q4    0.27
# 1960Q1    2.31
#           ...
# 2008Q3   -3.16
# 2008Q4   -8.79
# 2009Q1    0.94
# 2009Q2    3.37
# 2009Q3    3.56
# Freq: Q-DEC, Name: infl, Length: 203, dtype: float64

# %%
dates = pd.date_range('2000-01-01', periods=100)

# %%
ts = pd.Series(np.random.standard_normal(len(dates)), index=dates)

# %%
ts
# Out:
# 2000-01-01   -0.160530
# 2000-01-02    0.450748
# 2000-01-03    0.090115
# 2000-01-04    1.620958
# 2000-01-05    0.543749
#                 ...
# 2000-04-05    0.804758
# 2000-04-06    0.756300
# 2000-04-07   -0.823974
# 2000-04-08    0.406718
# 2000-04-09    1.932850
# Freq: D, Length: 100, dtype: float64

# %%
ts.resample('ME').mean()
# Out:
# 2000-01-31    0.244045
# 2000-02-29   -0.025136
# 2000-03-31    0.200340
# 2000-04-30    0.429944
# Freq: ME, dtype: float64

# %%
ts.resample('ME').mean().to_period()
# Out:
# 2000-01    0.244045
# 2000-02   -0.025136
# 2000-03    0.200340
# 2000-04    0.429944
# Freq: M, dtype: float64

# %%
dates = pd.date_range('2000-01-01', periods=12, freq='min')

# %%
ts = pd.Series(np.arange(len(dates)), index=dates)

# %%
ts
# Out:
# 2000-01-01 00:00:00     0
# 2000-01-01 00:01:00     1
# 2000-01-01 00:02:00     2
# 2000-01-01 00:03:00     3
# 2000-01-01 00:04:00     4
# 2000-01-01 00:05:00     5
# 2000-01-01 00:06:00     6
# 2000-01-01 00:07:00     7
# 2000-01-01 00:08:00     8
# 2000-01-01 00:09:00     9
# 2000-01-01 00:10:00    10
# 2000-01-01 00:11:00    11
# Freq: min, dtype: int64

# %%
ts.resample('5min').sum()
# Out:
# 2000-01-01 00:00:00    10
# 2000-01-01 00:05:00    35
# 2000-01-01 00:10:00    21
# Freq: 5min, dtype: int64

# %%
ts.resample('5min', closed='right').sum()
# Out:
# 1999-12-31 23:55:00     0
# 2000-01-01 00:00:00    15
# 2000-01-01 00:05:00    40
# 2000-01-01 00:10:00    11
# Freq: 5min, dtype: int64

# %%
ts.resample('5min', closed='right', label='right').sum()
# Out:
# 2000-01-01 00:00:00     0
# 2000-01-01 00:05:00    15
# 2000-01-01 00:10:00    40
# 2000-01-01 00:15:00    11
# Freq: 5min, dtype: int64

# %%
from pandas.tseries.frequencies import to_offset

# %%
result = ts.resample('5min', closed='right', label='right').sum()

# %%
result.index = result.index + to_offset('-1s')

# %%
result
# Out:
# 1999-12-31 23:59:59     0
# 2000-01-01 00:04:59    15
# 2000-01-01 00:09:59    40
# 2000-01-01 00:14:59    11
# Freq: 5min, dtype: int64

# %%
ts = pd.Series(np.random.permutation(np.arange(len(dates))), index=dates)

# %%
ts.resample('5min').ohlc()
# Out:
#                      open  high  low  close
# 2000-01-01 00:00:00     6     8    1      8
# 2000-01-01 00:05:00    11    11    3     10
# 2000-01-01 00:10:00     2     2    0      0

# %%
frame = pd.DataFrame(np.random.standard_normal((2, 4)),
                     index=pd.date_range('2000-01-01', periods=2,
                     freq='W-WED'),
                     columns=['Colorado', 'Texas', 'New York', 'Ohio'])

# %%
frame
# Out:
#             Colorado     Texas  New York      Ohio
# 2000-01-05  0.818311  1.043350 -1.228755 -1.499588
# 2000-01-12  0.328149  2.548712  0.130555  0.474188

# %%
df_daily = frame.resample('D').asfreq()

# %%
df_daily
# Out:
#             Colorado     Texas  New York      Ohio
# 2000-01-05  0.818311  1.043350 -1.228755 -1.499588
# 2000-01-06       NaN       NaN       NaN       NaN
# 2000-01-07       NaN       NaN       NaN       NaN
# 2000-01-08       NaN       NaN       NaN       NaN
# 2000-01-09       NaN       NaN       NaN       NaN
# 2000-01-10       NaN       NaN       NaN       NaN
# 2000-01-11       NaN       NaN       NaN       NaN
# 2000-01-12  0.328149  2.548712  0.130555  0.474188

# %%
frame.resample('D').ffill()
# Out:
#             Colorado     Texas  New York      Ohio
# 2000-01-05  0.818311  1.043350 -1.228755 -1.499588
# 2000-01-06  0.818311  1.043350 -1.228755 -1.499588
# 2000-01-07  0.818311  1.043350 -1.228755 -1.499588
# 2000-01-08  0.818311  1.043350 -1.228755 -1.499588
# 2000-01-09  0.818311  1.043350 -1.228755 -1.499588
# 2000-01-10  0.818311  1.043350 -1.228755 -1.499588
# 2000-01-11  0.818311  1.043350 -1.228755 -1.499588
# 2000-01-12  0.328149  2.548712  0.130555  0.474188

# %%
frame.resample('D').ffill(limit=2)
# Out:
#             Colorado     Texas  New York      Ohio
# 2000-01-05  0.818311  1.043350 -1.228755 -1.499588
# 2000-01-06  0.818311  1.043350 -1.228755 -1.499588
# 2000-01-07  0.818311  1.043350 -1.228755 -1.499588
# 2000-01-08       NaN       NaN       NaN       NaN
# 2000-01-09       NaN       NaN       NaN       NaN
# 2000-01-10       NaN       NaN       NaN       NaN
# 2000-01-11       NaN       NaN       NaN       NaN
# 2000-01-12  0.328149  2.548712  0.130555  0.474188

# %%
frame.resample('W-THU').ffill()
# Out:
#             Colorado     Texas  New York      Ohio
# 2000-01-06  0.818311  1.043350 -1.228755 -1.499588
# 2000-01-13  0.328149  2.548712  0.130555  0.474188

# %%
frame = pd.DataFrame(np.random.standard_normal((24,  4)),
                     index=pd.period_range('1-2000', '12-2001',
                                           freq='M'),
                    columns=['Colorado', 'Texas', "New York", 'Ohio'])

# %%
frame.head()
# Out:
#          Colorado     Texas  New York      Ohio
# 2000-01  0.576221  0.773588 -1.062430  0.636324
# 2000-02  1.237177  2.073056  2.047522 -1.077002
# 2000-03 -0.219951 -1.938732  0.246637  1.132323
# 2000-04  0.526296 -0.470050  2.461120 -1.669151
# 2000-05  0.978983 -1.482147 -0.425798  0.510445

# %%
annual_frame = frame.resample('Y-DEC').mean()

# %%
annual_frame
# Out:
#       Colorado     Texas  New York      Ohio
# 2000  0.192242 -0.058376  0.195880  0.111933
# 2001 -0.102748  0.504180  0.444606 -0.198263

# %%
annual_frame.resample('Q-DEC').ffill()
# Out:
#         Colorado     Texas  New York      Ohio
# 2000Q1  0.192242 -0.058376  0.195880  0.111933
# 2000Q2  0.192242 -0.058376  0.195880  0.111933
# 2000Q3  0.192242 -0.058376  0.195880  0.111933
# 2000Q4  0.192242 -0.058376  0.195880  0.111933
# 2001Q1 -0.102748  0.504180  0.444606 -0.198263
# 2001Q2 -0.102748  0.504180  0.444606 -0.198263
# 2001Q3 -0.102748  0.504180  0.444606 -0.198263
# 2001Q4 -0.102748  0.504180  0.444606 -0.198263

# %%
annual_frame.resample('Q-DEC', convention='end').asfreq()
# Out:
#         Colorado     Texas  New York      Ohio
# 2000Q4  0.192242 -0.058376  0.195880  0.111933
# 2001Q1       NaN       NaN       NaN       NaN
# 2001Q2       NaN       NaN       NaN       NaN
# 2001Q3       NaN       NaN       NaN       NaN
# 2001Q4 -0.102748  0.504180  0.444606 -0.198263

# %%
annual_frame.resample('Q-MAR').ffill()
# Out:
#         Colorado     Texas  New York      Ohio
# 2000Q4  0.192242 -0.058376  0.195880  0.111933
# 2001Q1  0.192242 -0.058376  0.195880  0.111933
# 2001Q2  0.192242 -0.058376  0.195880  0.111933
# 2001Q3  0.192242 -0.058376  0.195880  0.111933
# 2001Q4 -0.102748  0.504180  0.444606 -0.198263
# 2002Q1 -0.102748  0.504180  0.444606 -0.198263
# 2002Q2 -0.102748  0.504180  0.444606 -0.198263
# 2002Q3 -0.102748  0.504180  0.444606 -0.198263

# %%
N = 15

# %%
times = pd.date_range('2017-05-20 00:00', freq='1min', periods=N)

# %%
df = pd.DataFrame({'time': times,
                   'value': np.arange(N)})

# %%
df
# Out:
#                   time  value
# 0  2017-05-20 00:00:00      0
# 1  2017-05-20 00:01:00      1
# 2  2017-05-20 00:02:00      2
# 3  2017-05-20 00:03:00      3
# 4  2017-05-20 00:04:00      4
# 5  2017-05-20 00:05:00      5
# 6  2017-05-20 00:06:00      6
# 7  2017-05-20 00:07:00      7
# 8  2017-05-20 00:08:00      8
# 9  2017-05-20 00:09:00      9
# 10 2017-05-20 00:10:00     10
# 11 2017-05-20 00:11:00     11
# 12 2017-05-20 00:12:00     12
# 13 2017-05-20 00:13:00     13
# 14 2017-05-20 00:14:00     14

# %%
df.set_index('time').resample('5min').count()
# Out:
#                      value
# time
# 2017-05-20 00:00:00      5
# 2017-05-20 00:05:00      5
# 2017-05-20 00:10:00      5

# %%
df2 = pd.DataFrame({'time': times.repeat(3),
                    'key': np.tile(['a', 'b', 'c'], N),
                    'value': np.arange(N * 3.)})

# %%
df2.head()
# Out:
#                  time key  value
# 0 2017-05-20 00:00:00   a    0.0
# 1 2017-05-20 00:00:00   b    1.0
# 2 2017-05-20 00:00:00   c    2.0
# 3 2017-05-20 00:01:00   a    3.0
# 4 2017-05-20 00:01:00   b    4.0

# %%
time_key = pd.Grouper(freq='5min')

# %%
resampled = (df2.set_index('time')
             .groupby(['key', time_key])
             .sum())

# %%
resampled
# Out:
#                          value
# key time
# a   2017-05-20 00:00:00   30.0
#     2017-05-20 00:05:00  105.0
#     2017-05-20 00:10:00  180.0
# b   2017-05-20 00:00:00   35.0
#     2017-05-20 00:05:00  110.0
#     2017-05-20 00:10:00  185.0
# c   2017-05-20 00:00:00   40.0
#     2017-05-20 00:05:00  115.0
#     2017-05-20 00:10:00  190.0

# %%
resampled.reset_index()
# Out:
#   key                time  value
# 0   a 2017-05-20 00:00:00   30.0
# 1   a 2017-05-20 00:05:00  105.0
# 2   a 2017-05-20 00:10:00  180.0
# 3   b 2017-05-20 00:00:00   35.0
# 4   b 2017-05-20 00:05:00  110.0
# 5   b 2017-05-20 00:10:00  185.0
# 6   c 2017-05-20 00:00:00   40.0
# 7   c 2017-05-20 00:05:00  115.0
# 8   c 2017-05-20 00:10:00  190.0

# %%
close_px_all = pd.read_csv('../examples/stock_px.csv',
                           parse_dates=True, index_col=0)

# %%
close_px = close_px_all[['AAPL', 'MSFT', 'XOM']]

# %%
close_px = close_px.resample('B').ffill()

# %%
close_px['AAPL'].plot()
close_px['AAPL'].rolling(250).mean().plot()
# Out:
# <Axes: >

# %%
std250 = close_px['AAPL'].pct_change().rolling(250, min_periods=10).std()

# %%
std250[5:12]
# Out:
# 2003-01-09         NaN
# 2003-01-10         NaN
# 2003-01-13         NaN
# 2003-01-14         NaN
# 2003-01-15         NaN
# 2003-01-16    0.009628
# 2003-01-17    0.013818
# Freq: B, Name: AAPL, dtype: float64

# %%
std250.plot()
# Out:
# <Axes: >

# %%
expanding_mean = std250.expanding().mean()

# %%
import matplotlib.pyplot as plt

plt.style.use('grayscale')

# %%
close_px.rolling(60).mean().plot(logy=True)
# Out:
# <Axes: >

# %%
close_px.rolling('20D').mean()
# Out:
#                   AAPL       MSFT        XOM
# 2003-01-02    7.400000  21.110000  29.220000
# 2003-01-03    7.425000  21.125000  29.230000
# 2003-01-06    7.433333  21.256667  29.473333
# 2003-01-07    7.432500  21.425000  29.342500
# 2003-01-08    7.402000  21.402000  29.240000
# ...                ...        ...        ...
# 2011-10-10  389.351429  25.602143  72.527857
# 2011-10-11  388.505000  25.674286  72.835000
# 2011-10-12  388.531429  25.810000  73.400714
# 2011-10-13  388.826429  25.961429  73.905000
# 2011-10-14  391.038000  26.048667  74.185333
#
# [2292 rows x 3 columns]

# %%
aapl_px = close_px['AAPL']['2006':'2007']
ma30 = aapl_px.rolling(30, min_periods=20).mean()
ewma30 = aapl_px.ewm(span=30).mean()
aapl_px.plot(style='k-', label='Price')
ma30.plot(style='k--', label='Simple Moving Avg')
ewma30.plot(style='k-', label='EW MA')
plt.legend()

# %%
spx_px = close_px_all['SPX']
spx_rets = spx_px.pct_change()
returns = close_px.pct_change()
corr = returns['AAPL'].rolling(125, min_periods=100).corr(spx_rets)
plt.style.use('default')

corr.plot()
# Out:
# <Axes: >

# %%
corr = returns.rolling(125, min_periods=100).corr(spx_rets)
corr.plot()
# Out:
# <Axes: >

# %%
from scipy.stats import percentileofscore

# %%
def score_at_2percent(x):
    return percentileofscore(x, 0.02)

# %%
result = returns['AAPL'].rolling(250).apply(score_at_2percent)

# %%
result.plot()
# Out:
# <Axes: >
